# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np# Import the API key.

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citpy dependency
from citipy import citipy

# %%
# Create a lis for holding the cities
cities = []

# Identify nearest city for each long/lat combination
for coordinate in coordinates :
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #If city is unique, add it to cities list
    if city not in cities :
        cities.append(city)
        
# Count city list
len(cities)
# Out:
# 739

# %%
# Import requests libary
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Create an endpoint URL for a city.
        city_url = url + "&q=" + city.replace(" ","+")

        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]      
        city_weather_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
#                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | marrakesh
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | port lincoln
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | erdenet
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | la sarre
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | caravelas
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | trinidad
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | samarai
# Processing Record 23 of Set 1 | pawai
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint-francois
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | dunedin
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | rio grande
# Processing Record 38 of Set 1 | truth or consequences
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | asau
# Processing Record 41 of Set 1 | russell
# Processing Record 42 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | namibe
# Processing Record 46 of Set 1 | hobyo
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | tabou
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | verkh-usugli
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | kavaratti
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | bocana de paiwas
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | vanavara
# Processing Record 9 of Set 2 | saint-pierre
# Processing Record 10 of Set 2 | havoysund
# Processing Record 11 of Set 2 | okhotsk
# Processing Record 12 of Set 2 | johi
# Processing Record 13 of Set 2 | staroutkinsk
# Processing Record 14 of Set 2 | twin falls
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | leh
# Processing Record 17 of Set 2 | pedasi
# Processing Record 18 of Set 2 | saiha
# Processing Record 19 of Set 2 | hay river
# Processing Record 20 of Set 2 | yar-sale
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | alyangula
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | uinskoye
# Processing Record 27 of Set 2 | cartagena del chaira
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | puerto carreno
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | haines junction
# Processing Record 36 of Set 2 | ucluelet
# Processing Record 37 of Set 2 | kainantu
# Processing Record 38 of Set 2 | okakarara
# Processing Record 39 of Set 2 | port moresby
# Processing Record 40 of Set 2 | salalah
# Processing Record 41 of Set 2 | sola
# Processing Record 42 of Set 2 | imbituba
# Processing Record 43 of Set 2 | hami
# Processing Record 44 of Set 2 | waiouru
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | hudson bay
# Processing Record 49 of Set 2 | beringovskiy
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | puerto baquerizo moreno
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | the pas
# Processing Record 4 of Set 3 | chegdomyn
# Processing Record 5 of Set 3 | goderich
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | west odessa
# Processing Record 8 of Set 3 | san quintin
# Processing Record 9 of Set 3 | requena
# Processing Record 10 of Set 3 | batesville
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | yeppoon
# Processing Record 14 of Set 3 | iskateley
# Processing Record 15 of Set 3 | kavieng
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | lorengau
# Processing Record 18 of Set 3 | uruzgan
# Processing Record 19 of Set 3 | mackay
# Processing Record 20 of Set 3 | totness
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | glazov
# Processing Record 23 of Set 3 | hofn
# Processing Record 24 of Set 3 | tilichiki
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | arak
# Processing Record 29 of Set 3 | selma
# Processing Record 30 of Set 3 | kieta
# Processing Record 31 of Set 3 | kutum
# Processing Record 32 of Set 3 | rio gallegos
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | chokurdakh
# Processing Record 35 of Set 3 | mogzon
# Processing Record 36 of Set 3 | meulaboh
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | nanchang
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | belaya gora
# Processing Record 42 of Set 3 | chabahar
# Processing Record 43 of Set 3 | tiznit
# Processing Record 44 of Set 3 | paramonga
# Processing Record 45 of Set 3 | port hardy
# Processing Record 46 of Set 3 | bilibino
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | buraydah
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 3 of Set 4 | esso
# Processing Record 4 of Set 4 | lazaro cardenas
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | manono
# Processing Record 7 of Set 4 | guicheng
# City not found. Skipping...
# Processing Record 8 of Set 4 | poya
# Processing Record 9 of Set 4 | petauke
# Processing Record 10 of Set 4 | innisfail
# Processing Record 11 of Set 4 | comodoro rivadavia
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | valparaiso
# Processing Record 14 of Set 4 | tecoanapa
# Processing Record 15 of Set 4 | markdorf
# Processing Record 16 of Set 4 | villa carlos paz
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | los llanos de aridane
# Processing Record 19 of Set 4 | slave lake
# Processing Record 20 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | mitsamiouli
# Processing Record 23 of Set 4 | pangai
# Processing Record 24 of Set 4 | tazovskiy
# Processing Record 25 of Set 4 | benton harbor
# Processing Record 26 of Set 4 | makakilo city
# Processing Record 27 of Set 4 | qaanaaq
# Processing Record 28 of Set 4 | puerto del rosario
# Processing Record 29 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 30 of Set 4 | baruun-urt
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | deyang
# Processing Record 34 of Set 4 | slantsy
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | morgan hill
# Processing Record 37 of Set 4 | coihaique
# Processing Record 38 of Set 4 | ylivieska
# Processing Record 39 of Set 4 | tura
# Processing Record 40 of Set 4 | nara
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | tuskegee
# Processing Record 43 of Set 4 | palmas
# Processing Record 44 of Set 4 | churachandpur
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | aranos
# Processing Record 47 of Set 4 | mwanza
# Processing Record 48 of Set 4 | kashi
# Processing Record 49 of Set 4 | ulundurpettai
# City not found. Skipping...
# Processing Record 50 of Set 4 | sinalunga
# Processing Record 1 of Set 5 | calamar
# Processing Record 2 of Set 5 | yerkoy
# Processing Record 3 of Set 5 | kabompo
# Processing Record 4 of Set 5 | tucurui
# Processing Record 5 of Set 5 | galle
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | manggar
# Processing Record 8 of Set 5 | bowen
# Processing Record 9 of Set 5 | college
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | arona
# Processing Record 12 of Set 5 | komsomolskiy
# Processing Record 13 of Set 5 | tavira
# Processing Record 14 of Set 5 | hilo
# Processing Record 15 of Set 5 | la peca
# Processing Record 16 of Set 5 | brighton
# Processing Record 17 of Set 5 | pachino
# Processing Record 18 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | cangzhou
# Processing Record 21 of Set 5 | boca do acre
# Processing Record 22 of Set 5 | te anau
# Processing Record 23 of Set 5 | zhoucheng
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | el carrizo
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | anderson
# Processing Record 29 of Set 5 | aswan
# Processing Record 30 of Set 5 | moroni
# Processing Record 31 of Set 5 | castro
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | santa vitoria do palmar
# Processing Record 34 of Set 5 | tambopata
# Processing Record 35 of Set 5 | lata
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | mar del plata
# Processing Record 38 of Set 5 | kalakamati
# Processing Record 39 of Set 5 | jamestown
# Processing Record 40 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 41 of Set 5 | gorodishche
# Processing Record 42 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 5 | graaff-reinet
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | biltine
# Processing Record 48 of Set 5 | narasannapeta
# Processing Record 49 of Set 5 | namatanai
# Processing Record 50 of Set 5 | kanker
# Processing Record 1 of Set 6 | lubbock
# Processing Record 2 of Set 6 | quelimane
# Processing Record 3 of Set 6 | port elizabeth
# Processing Record 4 of Set 6 | kanniyakumari
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | kambove
# Processing Record 8 of Set 6 | bohuslav
# Processing Record 9 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 6 | thinadhoo
# Processing Record 11 of Set 6 | kaitangata
# Processing Record 12 of Set 6 | srednekolymsk
# Processing Record 13 of Set 6 | lebedyn
# Processing Record 14 of Set 6 | longyearbyen
# Processing Record 15 of Set 6 | yamethin
# Processing Record 16 of Set 6 | narsaq
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | latung
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | bitung
# Processing Record 21 of Set 6 | lasa
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | port blair
# Processing Record 24 of Set 6 | mayo
# Processing Record 25 of Set 6 | port macquarie
# Processing Record 26 of Set 6 | camacha
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | brandon
# Processing Record 29 of Set 6 | lebanon
# Processing Record 30 of Set 6 | vwawa
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | kuusamo
# Processing Record 33 of Set 6 | tabuk
# Processing Record 34 of Set 6 | geraldton
# Processing Record 35 of Set 6 | lusambo
# Processing Record 36 of Set 6 | paramirim
# Processing Record 37 of Set 6 | soyo
# Processing Record 38 of Set 6 | todos santos
# Processing Record 39 of Set 6 | ola
# Processing Record 40 of Set 6 | kupang
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | polunochnoye
# Processing Record 43 of Set 6 | kloulklubed
# Processing Record 44 of Set 6 | berlevag
# Processing Record 45 of Set 6 | faya
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | danielskuil
# Processing Record 48 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 6 | bama
# Processing Record 50 of Set 6 | abdulino
# Processing Record 1 of Set 7 | muros
# Processing Record 2 of Set 7 | oga
# Processing Record 3 of Set 7 | wangou
# Processing Record 4 of Set 7 | talnakh
# Processing Record 5 of Set 7 | tomatlan
# Processing Record 6 of Set 7 | mount darwin
# Processing Record 7 of Set 7 | lejanias
# Processing Record 8 of Set 7 | ishigaki
# Processing Record 9 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 7 | havre-saint-pierre
# Processing Record 12 of Set 7 | jasper
# Processing Record 13 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 7 | margate
# Processing Record 15 of Set 7 | naze
# Processing Record 16 of Set 7 | karratha
# Processing Record 17 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 7 | natagaima
# Processing Record 19 of Set 7 | motala
# Processing Record 20 of Set 7 | saldanha
# Processing Record 21 of Set 7 | sabang
# Processing Record 22 of Set 7 | soledade
# Processing Record 23 of Set 7 | severo-kurilsk
# Processing Record 24 of Set 7 | port-gentil
# Processing Record 25 of Set 7 | koygorodok
# Processing Record 26 of Set 7 | tabas
# Processing Record 27 of Set 7 | trosna
# Processing Record 28 of Set 7 | henties bay
# Processing Record 29 of Set 7 | aykhal
# Processing Record 30 of Set 7 | nacala
# Processing Record 31 of Set 7 | olafsvik
# Processing Record 32 of Set 7 | najran
# Processing Record 33 of Set 7 | norwich
# Processing Record 34 of Set 7 | batagay
# Processing Record 35 of Set 7 | carbonia
# Processing Record 36 of Set 7 | blagoyevo
# Processing Record 37 of Set 7 | maturin
# Processing Record 38 of Set 7 | reedley
# Processing Record 39 of Set 7 | vao
# Processing Record 40 of Set 7 | zavoronezhskoye
# Processing Record 41 of Set 7 | bilma
# Processing Record 42 of Set 7 | mehamn
# Processing Record 43 of Set 7 | sorong
# Processing Record 44 of Set 7 | ribeira grande
# Processing Record 45 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 46 of Set 7 | zyryanka
# Processing Record 47 of Set 7 | coquimbo
# Processing Record 48 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 7 | souillac
# Processing Record 50 of Set 7 | sao joao da barra
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | smithers
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | sambava
# Processing Record 5 of Set 8 | bata
# Processing Record 6 of Set 8 | miandrivazo
# Processing Record 7 of Set 8 | nome
# Processing Record 8 of Set 8 | rio cuarto
# Processing Record 9 of Set 8 | kaa-khem
# Processing Record 10 of Set 8 | male
# Processing Record 11 of Set 8 | qasigiannguit
# Processing Record 12 of Set 8 | provideniya
# Processing Record 13 of Set 8 | san jose
# Processing Record 14 of Set 8 | codrington
# Processing Record 15 of Set 8 | cayenne
# Processing Record 16 of Set 8 | saint-augustin
# Processing Record 17 of Set 8 | blatna
# Processing Record 18 of Set 8 | buala
# Processing Record 19 of Set 8 | jinchang
# Processing Record 20 of Set 8 | padang
# Processing Record 21 of Set 8 | pacific grove
# Processing Record 22 of Set 8 | kaeo
# Processing Record 23 of Set 8 | ilulissat
# Processing Record 24 of Set 8 | matucana
# Processing Record 25 of Set 8 | balyaga
# Processing Record 26 of Set 8 | puerto ayacucho
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | toora-khem
# Processing Record 29 of Set 8 | villanueva
# Processing Record 30 of Set 8 | tateyama
# Processing Record 31 of Set 8 | west wendover
# Processing Record 32 of Set 8 | ngunguru
# Processing Record 33 of Set 8 | verin
# Processing Record 34 of Set 8 | coahuayana
# Processing Record 35 of Set 8 | roma
# Processing Record 36 of Set 8 | lima
# Processing Record 37 of Set 8 | kirakira
# Processing Record 38 of Set 8 | laguna
# Processing Record 39 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 8 | richards bay
# Processing Record 41 of Set 8 | negara
# Processing Record 42 of Set 8 | dali
# Processing Record 43 of Set 8 | da lat
# Processing Record 44 of Set 8 | craig
# Processing Record 45 of Set 8 | kamen-rybolov
# Processing Record 46 of Set 8 | brae
# Processing Record 47 of Set 8 | qarqin
# Processing Record 48 of Set 8 | argos
# Processing Record 49 of Set 8 | mecca
# Processing Record 50 of Set 8 | durban
# Processing Record 1 of Set 9 | ulladulla
# Processing Record 2 of Set 9 | mahon
# Processing Record 3 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 4 of Set 9 | macklin
# Processing Record 5 of Set 9 | sistranda
# Processing Record 6 of Set 9 | salinopolis
# Processing Record 7 of Set 9 | cabedelo
# Processing Record 8 of Set 9 | san cristobal
# Processing Record 9 of Set 9 | bichena
# Processing Record 10 of Set 9 | norrtalje
# Processing Record 11 of Set 9 | camapua
# Processing Record 12 of Set 9 | yanam
# Processing Record 13 of Set 9 | kazachinskoye
# Processing Record 14 of Set 9 | dombas
# Processing Record 15 of Set 9 | marzuq
# Processing Record 16 of Set 9 | arroyo
# Processing Record 17 of Set 9 | horsham
# Processing Record 18 of Set 9 | natal
# Processing Record 19 of Set 9 | nalobikha
# Processing Record 20 of Set 9 | bhanpura
# Processing Record 21 of Set 9 | egvekinot
# Processing Record 22 of Set 9 | westport
# Processing Record 23 of Set 9 | caraballeda
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | antofagasta
# Processing Record 28 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 9 | nemuro
# Processing Record 30 of Set 9 | azle
# Processing Record 31 of Set 9 | leningradskiy
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | dukat
# Processing Record 34 of Set 9 | doha
# Processing Record 35 of Set 9 | hornepayne
# Processing Record 36 of Set 9 | sagaing
# Processing Record 37 of Set 9 | cap malheureux
# Processing Record 38 of Set 9 | dinajpur
# Processing Record 39 of Set 9 | sinnamary
# Processing Record 40 of Set 9 | metro
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | oranjestad
# Processing Record 43 of Set 9 | inongo
# Processing Record 44 of Set 9 | abha
# Processing Record 45 of Set 9 | axim
# Processing Record 46 of Set 9 | cienfuegos
# Processing Record 47 of Set 9 | otavi
# Processing Record 48 of Set 9 | ugoofaaru
# Processing Record 49 of Set 9 | yerbogachen
# Processing Record 50 of Set 9 | biak
# Processing Record 1 of Set 10 | immokalee
# Processing Record 2 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 10 | osakarovka
# Processing Record 4 of Set 10 | cotacachi
# Processing Record 5 of Set 10 | nuevo ideal
# Processing Record 6 of Set 10 | deulgaon raja
# Processing Record 7 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 10 | moiyabana
# City not found. Skipping...
# Processing Record 9 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 10 | turtas
# Processing Record 11 of Set 10 | pont-saint-esprit
# Processing Record 12 of Set 10 | totma
# Processing Record 13 of Set 10 | praia da vitoria
# Processing Record 14 of Set 10 | flin flon
# Processing Record 15 of Set 10 | aksu
# Processing Record 16 of Set 10 | alice springs
# Processing Record 17 of Set 10 | hellendoorn
# Processing Record 18 of Set 10 | lillooet
# Processing Record 19 of Set 10 | manesti
# Processing Record 20 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 21 of Set 10 | balaipungut
# Processing Record 22 of Set 10 | sechura
# Processing Record 23 of Set 10 | topolobampo
# Processing Record 24 of Set 10 | khorixas
# Processing Record 25 of Set 10 | panama city
# Processing Record 26 of Set 10 | marand
# Processing Record 27 of Set 10 | zhigansk
# Processing Record 28 of Set 10 | huarmey
# Processing Record 29 of Set 10 | kopavogur
# Processing Record 30 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | avera
# Processing Record 32 of Set 10 | burnie
# Processing Record 33 of Set 10 | alekseyevka
# Processing Record 34 of Set 10 | thunder bay
# Processing Record 35 of Set 10 | grand gaube
# Processing Record 36 of Set 10 | yantal
# Processing Record 37 of Set 10 | kemijarvi
# Processing Record 38 of Set 10 | raozan
# City not found. Skipping...
# Processing Record 39 of Set 10 | adrar
# Processing Record 40 of Set 10 | nata
# Processing Record 41 of Set 10 | tofield
# Processing Record 42 of Set 10 | ust-koksa
# Processing Record 43 of Set 10 | surab
# Processing Record 44 of Set 10 | mgachi
# Processing Record 45 of Set 10 | choma
# Processing Record 46 of Set 10 | barreirinha
# Processing Record 47 of Set 10 | takoradi
# Processing Record 48 of Set 10 | cairns
# Processing Record 49 of Set 10 | banjarmasin
# Processing Record 50 of Set 10 | nyurba
# Processing Record 1 of Set 11 | chahuites
# Processing Record 2 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 11 | bathsheba
# Processing Record 4 of Set 11 | nago
# Processing Record 5 of Set 11 | llata
# Processing Record 6 of Set 11 | zhuanghe
# Processing Record 7 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 11 | karwar
# Processing Record 9 of Set 11 | green river
# Processing Record 10 of Set 11 | jalingo
# Processing Record 11 of Set 11 | farafangana
# Processing Record 12 of Set 11 | hanyang
# Processing Record 13 of Set 11 | tezu
# Processing Record 14 of Set 11 | provost
# Processing Record 15 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 11 | kang
# Processing Record 17 of Set 11 | eyl
# Processing Record 18 of Set 11 | barcelona
# Processing Record 19 of Set 11 | boa vista
# Processing Record 20 of Set 11 | leira
# Processing Record 21 of Set 11 | naples
# Processing Record 22 of Set 11 | tingi
# Processing Record 23 of Set 11 | mildura
# Processing Record 24 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 11 | pimenta bueno
# Processing Record 26 of Set 11 | christchurch
# Processing Record 27 of Set 11 | genhe
# Processing Record 28 of Set 11 | novikovo
# Processing Record 29 of Set 11 | kabalo
# Processing Record 30 of Set 11 | prince albert
# Processing Record 31 of Set 11 | daru
# Processing Record 32 of Set 11 | yinchuan
# Processing Record 33 of Set 11 | tarko-sale
# Processing Record 34 of Set 11 | concepcion del uruguay
# Processing Record 35 of Set 11 | hollola
# Processing Record 36 of Set 11 | swan river
# Processing Record 37 of Set 11 | taltal
# Processing Record 38 of Set 11 | sorland
# Processing Record 39 of Set 11 | finschhafen
# Processing Record 40 of Set 11 | dolhesti
# Processing Record 41 of Set 11 | bang bo
# Processing Record 42 of Set 11 | jiamusi
# Processing Record 43 of Set 11 | taguatinga
# Processing Record 44 of Set 11 | enid
# Processing Record 45 of Set 11 | petawawa
# Processing Record 46 of Set 11 | baracoa
# Processing Record 47 of Set 11 | werneck
# Processing Record 48 of Set 11 | arenapolis
# Processing Record 49 of Set 11 | sakaiminato
# Processing Record 50 of Set 11 | verkhoyansk
# Processing Record 1 of Set 12 | bafq
# Processing Record 2 of Set 12 | jiangdu
# Processing Record 3 of Set 12 | deputatskiy
# Processing Record 4 of Set 12 | kiama
# Processing Record 5 of Set 12 | paamiut
# Processing Record 6 of Set 12 | radford
# Processing Record 7 of Set 12 | aquin
# Processing Record 8 of Set 12 | champerico
# Processing Record 9 of Set 12 | minab
# Processing Record 10 of Set 12 | honiara
# Processing Record 11 of Set 12 | rocha
# Processing Record 12 of Set 12 | moyale
# Processing Record 13 of Set 12 | nanfeng
# Processing Record 14 of Set 12 | mizan teferi
# Processing Record 15 of Set 12 | kasongo-lunda
# Processing Record 16 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 12 | sobolevo
# Processing Record 18 of Set 12 | faanui
# Processing Record 19 of Set 12 | benguela
# Processing Record 20 of Set 12 | juneau
# Processing Record 21 of Set 12 | ust-nera
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | warman
# Processing Record 24 of Set 12 | bonthe
# Processing Record 25 of Set 12 | grand bank
# Processing Record 26 of Set 12 | pundaguitan
# Processing Record 27 of Set 12 | payo
# Processing Record 28 of Set 12 | lander
# Processing Record 29 of Set 12 | muroto
# Processing Record 30 of Set 12 | baker city
# Processing Record 31 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 32 of Set 12 | dukhovnitskoye
# Processing Record 33 of Set 12 | uberaba
# Processing Record 34 of Set 12 | manokwari
# Processing Record 35 of Set 12 | neftcala
# Processing Record 36 of Set 12 | port hedland
# Processing Record 37 of Set 12 | plettenberg bay
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | playas
# Processing Record 40 of Set 12 | razdolinsk
# Processing Record 41 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 12 | vila franca do campo
# Processing Record 43 of Set 12 | muisne
# Processing Record 44 of Set 12 | dinagat
# Processing Record 45 of Set 12 | hervey bay
# Processing Record 46 of Set 12 | urumqi
# Processing Record 47 of Set 12 | pathein
# Processing Record 48 of Set 12 | ostrovnoy
# Processing Record 49 of Set 12 | yelizovo
# Processing Record 50 of Set 12 | svecha
# Processing Record 1 of Set 13 | atar
# Processing Record 2 of Set 13 | beira
# Processing Record 3 of Set 13 | yumen
# Processing Record 4 of Set 13 | koslan
# Processing Record 5 of Set 13 | zimovniki
# Processing Record 6 of Set 13 | manama
# Processing Record 7 of Set 13 | zonguldak
# Processing Record 8 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 13 | ayan
# Processing Record 10 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 13 | itaqui
# Processing Record 12 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 13 | erdaojiang
# Processing Record 14 of Set 13 | ulaangom
# Processing Record 15 of Set 13 | mombetsu
# Processing Record 16 of Set 13 | qax
# Processing Record 17 of Set 13 | cabra
# Processing Record 18 of Set 13 | port shepstone
# Processing Record 19 of Set 13 | xingcheng
# Processing Record 20 of Set 13 | kruisfontein
# Processing Record 21 of Set 13 | riyadh
# Processing Record 22 of Set 13 | luleburgaz
# Processing Record 23 of Set 13 | buenos aires
# Processing Record 24 of Set 13 | aripuana
# Processing Record 25 of Set 13 | asfi
# Processing Record 26 of Set 13 | omsukchan
# Processing Record 27 of Set 13 | andilamena
# Processing Record 28 of Set 13 | paka
# Processing Record 29 of Set 13 | zambezi
# Processing Record 30 of Set 13 | quartucciu
# Processing Record 31 of Set 13 | hrubieszow
# Processing Record 32 of Set 13 | barkly west
# Processing Record 33 of Set 13 | murgab
# Processing Record 34 of Set 13 | broken hill
# Processing Record 35 of Set 13 | nkongsamba
# Processing Record 36 of Set 13 | hanmer springs
# Processing Record 37 of Set 13 | nambucca heads
# Processing Record 38 of Set 13 | peruibe
# Processing Record 39 of Set 13 | kichmengskiy gorodok
# Processing Record 40 of Set 13 | atikokan
# Processing Record 41 of Set 13 | khandbari
# Processing Record 42 of Set 13 | stornoway
# Processing Record 43 of Set 13 | viedma
# Processing Record 44 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 13 | gat
# Processing Record 46 of Set 13 | diamantino
# Processing Record 47 of Set 13 | hirara
# Processing Record 48 of Set 13 | bondo
# Processing Record 49 of Set 13 | emerald
# Processing Record 50 of Set 13 | pangkalanbuun
# Processing Record 1 of Set 14 | miracema do tocantins
# Processing Record 2 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 14 | walvis bay
# Processing Record 4 of Set 14 | jaisalmer
# Processing Record 5 of Set 14 | katesh
# Processing Record 6 of Set 14 | arman
# Processing Record 7 of Set 14 | puurmani
# Processing Record 8 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 14 | caceres
# Processing Record 10 of Set 14 | tosya
# Processing Record 11 of Set 14 | griffith
# Processing Record 12 of Set 14 | juliaca
# Processing Record 13 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 14 of Set 14 | oktyabrskoye
# Processing Record 15 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 14 | norman wells
# Processing Record 17 of Set 14 | canmore
# Processing Record 18 of Set 14 | vila
# Processing Record 19 of Set 14 | dubti
# Processing Record 20 of Set 14 | mahibadhoo
# Processing Record 21 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 14 | lakes entrance
# Processing Record 23 of Set 14 | ipixuna
# Processing Record 24 of Set 14 | saint anthony
# Processing Record 25 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 14 | aketi
# Processing Record 27 of Set 14 | letlhakane
# Processing Record 28 of Set 14 | sidi ali
# Processing Record 29 of Set 14 | rumonge
# Processing Record 30 of Set 14 | tual
# Processing Record 31 of Set 14 | carauari
# Processing Record 32 of Set 14 | sibulao
# Processing Record 33 of Set 14 | luorong
# Processing Record 34 of Set 14 | tuatapere
# Processing Record 35 of Set 14 | ascension
# Processing Record 36 of Set 14 | monrovia
# Processing Record 37 of Set 14 | santa maria
# Processing Record 38 of Set 14 | filadelfia
# Processing Record 39 of Set 14 | borogontsy
# Processing Record 40 of Set 14 | waipawa
# Processing Record 41 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 14 | omutninsk
# Processing Record 43 of Set 14 | tiarei
# Processing Record 44 of Set 14 | wake forest
# Processing Record 45 of Set 14 | lazurne
# Processing Record 46 of Set 14 | morant bay
# Processing Record 47 of Set 14 | kalianget
# Processing Record 48 of Set 14 | dwarka
# Processing Record 49 of Set 14 | mount isa
# Processing Record 50 of Set 14 | strunino
# Processing Record 1 of Set 15 | kimbe
# Processing Record 2 of Set 15 | gambela
# Processing Record 3 of Set 15 | the valley
# Processing Record 4 of Set 15 | outram
# Processing Record 5 of Set 15 | tsiroanomandidy
# Processing Record 6 of Set 15 | mananjary
# Processing Record 7 of Set 15 | linkoping
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | paengaroa
# Processing Record 10 of Set 15 | chapais
# Processing Record 11 of Set 15 | kattivakkam
# Processing Record 12 of Set 15 | podporozhye
# Processing Record 13 of Set 15 | itoman
# Processing Record 14 of Set 15 | breves
# Processing Record 15 of Set 15 | sakakah
# Processing Record 16 of Set 15 | ghanzi
# Processing Record 17 of Set 15 | carutapera
# Processing Record 18 of Set 15 | inhambane
# Processing Record 19 of Set 15 | flinders
# Processing Record 20 of Set 15 | nha trang
# Processing Record 21 of Set 15 | portland
# Processing Record 22 of Set 15 | calobre
# City not found. Skipping...
# Processing Record 23 of Set 15 | ust-omchug
# Processing Record 24 of Set 15 | fond du lac
# Processing Record 25 of Set 15 | acarau
# Processing Record 26 of Set 15 | nelson bay
# Processing Record 27 of Set 15 | yaan
# Processing Record 28 of Set 15 | begoro
# Processing Record 29 of Set 15 | nouadhibou
# Processing Record 30 of Set 15 | peleduy
# Processing Record 31 of Set 15 | illela
# Processing Record 32 of Set 15 | dongning
# Processing Record 33 of Set 15 | pontianak
# Processing Record 34 of Set 15 | fort nelson
# Processing Record 35 of Set 15 | ixtapa
# Processing Record 36 of Set 15 | half moon bay
# Processing Record 37 of Set 15 | hun
# Processing Record 38 of Set 15 | agapovka
# Processing Record 39 of Set 15 | limbang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add weather data to a new Data Frame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     41.92        68          77
# 1     Marrakesh      MA  31.6315   -8.0083     86.07        48          40
# 2    Nikolskoye      RU  59.7035   30.7861     66.87        71          59
# 3  Port Lincoln      AU -34.7333  135.8667     51.26        76           3
# 4        Kodiak      US  57.7900 -152.4072     60.31        67         100
#
#    Wind Speed Current Description
# 0        9.22       broken clouds
# 1        8.05    scattered clouds
# 2        4.70       broken clouds
# 3        5.48           clear sky
# 4       10.36     overcast clouds

# %%
# Export data frame as WeatherPy_Database.csv into Weather_Database folder
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
